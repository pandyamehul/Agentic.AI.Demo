# %% [markdown]
# ## Tweet Bot Agent
#
# - `Tweet Bot`  writes a creative, engaging tweet (≤280 characters) about a given topic using OpenAI Agents SDK.
# - The tweet should include at least one emoji and a hashtag.
# - The agent will use the `gpt-5.1-mini` model to generate the tweet.

# %%
# Install the specific version of openai-agents
# %pip uninstall -y openai-agents
# %pip install --upgrade pydantic
# %pip install --no-cache-dir openai-agents==0.2.2
# %pip install python-dotenv langchain-openai==0.2.1
# Out:
# Found existing installation: openai-agents 0.17.2
# Uninstalling openai-agents-0.17.2:
#   Successfully uninstalled openai-agents-0.17.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import os
from openai import OpenAI
from IPython.display import display, Markdown

# Import the Agent class to create and manage AI agents
from agents import Agent, Runner

# Import the Runner class, which is used to run an agent and get its output
# from agents import Runner

# This will be used to load the API key from the .env file
from dotenv import load_dotenv

# %%
def print_markdown(text):
    """Displays text as Markdown in Jupyter."""
    display(Markdown(text))

# %%
load_dotenv()

# Get the OpenAI API key from environment variables or prompt if missing
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    from getpass import getpass
    openai_api_key = getpass("OpenAI API key (will not be echoed): ")

# Ensure the agents/OpenAI client can read the key via the environment variable
if openai_api_key:
    os.environ["OPENAI_API_KEY"] = openai_api_key

# Configure the OpenAI Client using our key
openai_client = OpenAI(api_key=openai_api_key)
print("OpenAI client successfully configured.")
# Out:
# OpenAI client successfully configured.

# %%
tweet_bot_instructions = """
Instruction:
Write a short, engaging tweet (≤300 characters) about the given topic. The tweet must include at least one relevant emoji and one relevant hashtag.

Context:
You are **TweetBot**, a witty and creative social-media expert known for crafting viral tweets.

Input:
A topic provided by the user.

Output:
A single tweet (≤300 characters) about the topic, containing at least one relevant emoji and one relevant hashtag.
"""

# %%
# Let's define the Agent
tweet_bot_agent = Agent(
    name = "Tweet Bot",
    instructions = tweet_bot_instructions,
    model = "gpt-5-mini"
)

print(f"Agent '{tweet_bot_agent.name}' created successfully!")
# Out:
# Agent 'Tweet Bot' created successfully!

# %%
# Let's run the agent and test it out!
topic = "The future and need of renewable energy"
print_markdown(f"\nAsking Tweet Bot to write a tweet about: '{topic}'")

tweet_response = await Runner.run(starting_agent=tweet_bot_agent, input=topic)
print_markdown("\n🤖 Tweet Bot's Response:\n")
print_markdown(tweet_response.final_output)
# Out:
# Asking Tweet Bot to write a tweet about: 'The future and need of renewable energy'
# 🤖 Tweet Bot's Response:
# The future runs on wind, sun & smart ideas — renewables aren't optional, they're inevitable. Swap fossil fumes for clean watts ⚡️🌞🌬️ Invest, innovate, act now — power to the planet and the people. #RenewableEnergy #ClimateAction
